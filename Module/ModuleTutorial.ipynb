# %%
from label_generation import *
import openai
import pickle
import json

# %% [markdown]
# ### Get the API Key

# %%
config_path = "../config.ini"
openai.api_key = get_api_key(config_path)

# %% [markdown]
# ### Generate or Load in Summaries

# %% [markdown]
# There must be a dictionary mapping each file to a summary of the contents of the file. Summaries are costly to generate and can be generated using the script in 'summarize.py'. Instead of summaries, the whole text can simply be passed in. <br>
#
# {file name : summary}

# %% [markdown]
# #### Reading in summaries

# %%
with open("../Data/openai_summaries_2", "rb") as fp:
    summaries = pickle.load(fp)

# %% [markdown]
# ### Generate or Load in Embedddings

# %% [markdown]
# Similar to the summaries, there must be a dictionary mapping each file to an embedding vector. <br>
#
# {file name : embedding}

# %% [markdown]
# #### Reading in Embeddings

# %%
with open("../Helper Stuff/embeddings.json") as f:
    embeddings = json.load(f)

# %% [markdown]
# ### Generating Labels

# %% [markdown]
# With these imputs a linkage matrix containing labels will be generated. Contents of each row in the linkage matrix are summarized below: <br> <br>
# Index 0: Contains index of cluster 1 used to create new cluster <br>
# Index 1: Contains index of cluster 2 used to create new cluster <br>
# Index 2: Contains distance between cluster 1 and cluster 2 <br>
# Index 3: Contains number of leaves contained within this cluster <br>
# Index 4: Contains the Label for this cluster <br>
# Index 5: Contains the labels of this clusters children which were used to generate the label for this cluster <br>

# %%
links = generate_labels(embeddings, summaries)
# Out:
#   0%|          | 0/593 [00:00<?, ?it/s]
# Exception: The model: `gpt-4-0314` does not exist
# Error with rate limit waiting 60 seconds
#   0%|          | 0/593 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# File ~/Desktop/Label-Generation/Module/label_generation.py:26, in determine_label(topics, model_engine, prompt)
#      25 try:
# ---> 26     response = openai.ChatCompletion.create(model = model_engine, messages = [prompt])["choices"][0]["message"]["content"]
#      27 except Exception as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      24 try:
# ---> 25     return super().create(*args, **kwargs)
#      26 except TryAgain as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     138 (
#     139     deployment_id,
#     140     engine,
#    (...)
#     150     api_key, api_base, api_type, api_version, organization, **params
#     151 )
# --> 153 response, _, api_key = requestor.request(
#     154     "post",
#     155     url,
#     156     params=params,
#     157     headers=headers,
#     158     stream=stream,
#     159     request_id=request_id,
#     160     request_timeout=request_timeout,
#     161 )
#     163 if stream:
#     164     # must be an iterator
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/api_requestor.py:226, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     216 result = self.request_raw(
#     217     method.lower(),
#     218     url,
#    (...)
#     224     request_timeout=request_timeout,
#     225 )
# --> 226 resp, got_stream = self._interpret_response(result, stream)
#     227 return resp, got_stream, self.api_key
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/api_requestor.py:620, in APIRequestor._interpret_response(self, result, stream)
#     618 else:
#     619     return (
# --> 620         self._interpret_response_line(
#     621             result.content.decode("utf-8"),
#     622             result.status_code,
#     623             result.headers,
#     624             stream=False,
#     625         ),
#     626         False,
#     627     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/api_requestor.py:683, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     682 if stream_error or not 200 <= rcode < 300:
# --> 683     raise self.handle_error_response(
#     684         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     685     )
#     686 return resp
#
# InvalidRequestError: The model: `gpt-4-0314` does not exist
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/kaanankharwa/Desktop/Label-Generation/Module/ModuleTutorial.ipynb Cell 14 in 1
# ----> <a href='vscode-notebook-cell:/Users/kaanankharwa/Desktop/Label-Generation/Module/ModuleTutorial.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> links = generate_labels(embeddings, summaries)
#
# File ~/Desktop/Label-Generation/Module/label_generation.py:60, in generate_labels(embeddings, summaries)
#      58         summary2 = [links[i][4]]
#      59     cluster.append(summary1 + summary2)
# ---> 60     cluster[4] = determine_label(cluster[5])
#      61     links[i] = cluster
#      62 return links
#
# File ~/Desktop/Label-Generation/Module/label_generation.py:30, in determine_label(topics, model_engine, prompt)
#      28     print("Exception: {}".format(e))
#      29     print("Error with rate limit waiting 60 seconds")
# ---> 30     time.sleep(60)
#      31     response = openai.ChatCompletion.create(model = model_engine, messages = [prompt])["choices"][0]["message"]["content"]
#      32 return response
#
# KeyboardInterrupt:

# %% [markdown]
# ### Output

# %%
links
# Out:
# [[399.0,
#   594.0,
#   0.42786448395325166,
#   3.0,
#   'Knowledge seekers.',
#   ['Book - Philosophy - Alchemy', 'Occultism.']],
#  [204.0,
#   595.0,
#   0.15685175833221093,
#   3.0,
#   'Discounts.',
#   ['Category: Theater.', 'Literature/purchase: discount.']],
#  [303.0,
#   596.0,
#   0.1652177944881287,
#   4.0,
#   'None.',
#   ['Shakespearean play analysis.', 'Discounts.']],
#  [303.0,
#   596.0,
#   0.1652177944881287,
#   4.0,
#   'None.',
#   ['Shakespearean play analysis.', 'Discounts.']],
#  [277.0,
#   379.0,
#   0.1695001531610153,
#   2.0,
#   'Russian Fiction Books.',
#   ['Literature, Russian, Free.', 'Book, Fiction, Russian-Language.']],
#  [288.0,
#   599.0,
#   0.4305627017428426,
#   3.0,
#   'STEM resources.',
#   ['Engineering book.', 'Technology education.']],
#  [216.0,
#   407.0,
#   0.19415253415551106,
#   2.0,
#   'Predictive text.',
#   ['Prophecy book.', 'Prophecies.']],
#  [243.0,
#   601.0,
#   0.4949923818620001,
#   3.0,
#   'Words and information',
#   ['Book - Bernard Werber - Encyclopedia', 'Reference material.']],
#  [320.0,
#   602.0,
#   0.23869318261055456,
#   3.0,
#   'Cats.',
#   ['Book: Felines, French, Damaged.', 'Animals.']],
#  [60.0,
#   501.0,
#   0.21787985254782538,
#   2.0,
#   'Project management.',
#   ['Garden renovation project.', 'Entrepreneur in multiple industries.']],
#  [571.0,
#   604.0,
#   0.45150205276241945,
#   3.0,
#   'Adjectives.',
#   ['Text type: definition. \nVocabulary category: French adjective.',
#    'Descriptive words.']],
#  [369.0,
#   605.0,
#   0.2637566677635072,
#   3.0,
#   'Animals.',
#   ['Animal kingdom.', 'Zoology book.']],
#  [260.0,
#   606.0,
#   0.24493412575569354,
#   3.0,
#   'Damaged print publication.',
#   ['Book, Zoology, 1969.', 'Damaged book.']],
#  [421.0,
#   607.0,
#   0.25703234670494973,
#   4.0,
#   'Feline book.',
#   ['Book on animals - French - 1969.', 'Cats.']],
#  [218.0,
#   608.0,
#   0.26946032372937095,
#   3.0,
#   'French reference book.',
#   ['Book on French culture.', 'Language reference.']],
#  [468.0,
#   609.0,
#   0.2521809590352677,
#   3.0,
#   'French animals.',
#   ['French animal book.', 'Animals']],
#  [260.0,
#   606.0,
#   0.24493412575569354,
#   3.0,
#   'Damaged print publication.',
#   ['Book, Zoology, 1969.', 'Damaged book.']],
#  [468.0,
#   609.0,
#   0.2521809590352677,
#   3.0,
#   'French animals.',
#   ['French animal book.', 'Animals']],
#  [393.0,
#   612.0,
#   0.2814792201289032,
#   3.0,
#   'Animals.',
#   ['Animal habits.', 'French animals.']],
#  [610.0,
#   613.0,
#   0.2760876224962299,
#   7.0,
#   'Print damage.',
#   ['Damaged print publication.', 'Feline book.']],
#  [386.0,
#   614.0,
#   0.2811599203477078,
#   4.0,
#   'Animals',
#   ['Animal book.', 'Animals.']],
#  [245.0,
#   615.0,
#   0.3384390449851475,
#   4.0,
#   'French language.',
#   ['Language: French.', 'French reference book.']],
#  [395.0,
#   616.0,
#   0.33260465965854047,
#   3.0,
#   'Narrative prose.',
#   ['Short Stories', 'Literary works.']],
#  [610.0,
#   613.0,
#   0.2760876224962299,
#   7.0,
#   'Print damage.',
#   ['Damaged print publication.', 'Feline book.']],
#  [265.0,
#   336.0,
#   0.27787245946902855,
#   2.0,
#   'French animals.',
#   ['French animal book', 'Animals - French.']],
#  [194.0,
#   329.0,
#   0.27830716907326,
#   2.0,
#   'Books.',
#   ['books/classic-french, books/physical, books/other, books/not-read, books/cardboard',
#    'Travelogue.']],
#  [617.0,
#   620.0,
#   0.28237717861878714,
#   11.0,
#   'Ink stains.',
#   ['Print damage.', 'Animals']],
#  [393.0,
#   612.0,
#   0.2814792201289032,
#   3.0,
#   'Animals.',
#   ['Animal habits.', 'French animals.']],
#  [621.0,
#   622.0,
#   0.28725876100748227,
#   14.0,
#   'Spots.',
#   ['Animals.', 'Ink stains.']],
#  [434.0,
#   623.0,
#   0.2886488912705441,
#   15.0,
#   'Dalmatian spots.',
#   ['French animal book.', 'Spots.']],
#  [262.0,
#   624.0,
#   0.29083089151469665,
#   16.0,
#   'Dalmatian.',
#   ['Category: Book, Animals, Vintage.', 'Dalmatian spots.']],
#  [210.0,
#   625.0,
#   0.295137317070683,
#   17.0,
#   'None.',
#   ['Python book', 'Dalmatian.']],
#  [363.0,
#   626.0,
#   0.29869926438399264,
#   18.0,
#   'Animals.',
#   ['Book: Animals (French, 200 pages)', 'None.']],
#  [312.0,
#   627.0,
#   0.29899955006194406,
#   19.0,
#   'French fauna',
#   ['French animal book', 'Animals.']],
#  [618.0,
#   628.0,
#   0.3000467119708025,
#   21.0,
#   'French fauna.',
#   ['French animals.', 'French fauna']],
#  [611.0,
#   629.0,
#   0.30281999805028437,
#   24.0,
#   'French wildlife.',
#   ['French animals.', 'French fauna.']],
#  [281.0,
#   630.0,
#   0.3067858929649913,
#   25.0,
#   'French animals.',
#   ['French animal book.', 'French wildlife.']],
#  [447.0,
#   631.0,
#   0.3309066250757052,
#   26.0,
#   'Animals.',
#   ['Animal book.', 'French animals.']],
#  [179.0,
#   632.0,
#   0.31441550331032514,
#   3.0,
#   'Trimix.',
#   ['Diving gas: hypoxic trimix.', 'Gas mixture.']],
#  [180.0,
#   633.0,
#   0.4237935070645278,
#   4.0,
#   'Underwater breathing mixtures.',
#   ['Mixed-gas diving.', 'Trimix.']],
#  [263.0,
#   451.0,
#   0.3167431542709543,
#   2.0,
#   'Music books.',
#   ['Book on music history.', 'Book (music biography)']],
#  [424.0,
#   635.0,
#   0.4009077407368815,
#   3.0,
#   'Acquisition - Francophone.',
#   ['Purchase - Literature.', 'French literature.']],
#  [302.0,
#   636.0,
#   0.4098754743082107,
#   27.0,
#   'None.',
#   ['Book edition.', 'Animals.']],
#  [473.0,
#   637.0,
#   0.3511600764693516,
#   4.0,
#   'Written stories.',
#   ['Literature.', 'Narrative prose.']],
#  [297.0,
#   315.0,
#   0.3347043121355429,
#   2.0,
#   'Mathematics literature.',
#   ['Mathematical poetry.', 'Mathematics book.']],
#  [446.0,
#   639.0,
#   0.41506035109161155,
#   5.0,
#   'Words and terms.',
#   ['Fashion dictionary.', 'French language.']],
#  [66.0,
#   94.0,
#   0.34313507541502286,
#   2.0,
#   'Note-taking.',
#   ['Note-taking method.', 'Study notes.']],
#  [231.0,
#   641.0,
#   0.34861128802291624,
#   3.0,
#   'Music.',
#   ['Jazz history book.', 'Jazz.']],
#  [397.0,
#   642.0,
#   0.3925822795579689,
#   4.0,
#   'Musical education.',
#   ['Music instruction.', 'Music.']],
#  [640.0,
#   643.0,
#   0.3509236394405459,
#   4.0,
#   'Organization skills.',
#   ['Note-taking.', 'Efficient organization.']],
#  [157.0,
#   644.0,
#   0.35154161847134374,
#   5.0,
#   'Notebook tool.',
#   ['Note-taking aid.', 'Organization skills.']],
#  [388.0,
#   645.0,
#   0.3580261360977378,
#   5.0,
#   'Written stories.',
#   ['book, literature, French', 'Written stories.']],
#  [157.0,
#   644.0,
#   0.35154161847134374,
#   5.0,
#   'Notebook tool.',
#   ['Note-taking aid.', 'Organization skills.']],
#  [325.0,
#   647.0,
#   0.36348179562062183,
#   3.0,
#   'Learning tools.',
#   ['AI Technology', '"Book subject"']],
#  [597.0,
#   648.0,
#   0.36028707405752275,
#   9.0,
#   'Imaginative narratives.',
#   ['None.', 'Written stories.']],
#  [438.0,
#   649.0,
#   0.39184627311547554,
#   3.0,
#   'Adventure fiction.',
#   ['Book / Fiction / Jules Verne.', 'Book genres.']],
#  [318.0,
#   650.0,
#   0.36497569146518155,
#   10.0,
#   'Creative storytelling.',
#   ['Fiction literature.', 'Imaginative narratives.']],
#  [101.0,
#   651.0,
#   0.4314691833866965,
#   3.0,
#   'Expectation analysis.',
#   ['Book marketing rhetoric.', 'Criticism expectation.']],
#  [209.0,
#   652.0,
#   0.39233436335360866,
#   3.0,
#   'Theory.',
#   ['Book - Freud - Philosophy', 'Geometry.']],
#  [305.0,
#   653.0,
#   0.4201347517366654,
#   3.0,
#   'Biography.',
#   ['Author: James Brown.', 'Life stories.']],
#  [300.0,
#   462.0,
#   0.36265404293359527,
#   2.0,
#   'Programming language.',
#   ['Web programming.', 'Programming book.']],
#  [214.0,
#   655.0,
#   0.419702531474567,
#   4.0,
#   'Information sources.',
#   ['Book, philosophy.', 'Learning tools.']],
#  [227.0,
#   656.0,
#   0.4010622933563719,
#   11.0,
#   'Narrative creation.',
#   ['Biography.', 'Creative storytelling.']],
#  [222.0,
#   444.0,
#   0.3706511065151886,
#   2.0,
#   'Music Theory.',
#   ['Category: Book - Music - Purchase', 'Music theory book.']],
#  [155.0,
#   658.0,
#   0.41328867139255576,
#   3.0,
#   'Digital representation.',
#   ['Computer systems: binary.', 'Unrestricted creativity.']],
#  [10.0,
#   125.0,
#   0.3742046115877992,
#   2.0,
#   'Reading comprehension.',
#   ['Active reading levels.', 'Active reading levels.']],
#  [478.0,
#   660.0,
#   0.4592451451365257,
#   3.0,
#   'Leadership perspective.',
#   ['Book on leadership.', 'Leadership belief.']],
#  [646.0,
#   661.0,
#   0.3782773796939892,
#   7.0,
#   'Writing tool.',
#   ['Notebook tool.', 'Note-taking.']],
#  [390.0,
#   662.0,
#   0.3880508343732944,
#   8.0,
#   'Writing aid.',
#   ['Book/Non-fiction/Education', 'Writing tool.']],
#  [333.0,
#   663.0,
#   0.3984420768840866,
#   3.0,
#   'Analysis of literature.',
#   ['Book review.', 'Book review']],
#  [242.0,
#   664.0,
#   0.3923492191694857,
#   3.0,
#   'Language & Writing.',
#   ['Book on Philosophy', 'Memoir in French.']],
#  [659.0,
#   665.0,
#   0.3996272505913155,
#   4.0,
#   'Interpretive skills.',
#   ['Reading comprehension.', 'Literary analysis.']],
#  [477.0,
#   666.0,
#   0.388826089526487,
#   3.0,
#   'Music knowledge.',
#   ['Music book.', 'Music history']],
#  [337.0,
#   367.0,
#   0.3875590244529225,
#   2.0,
#   'Book sale.',
#   ['Book on sale.', 'Book/Economics/France.']],
#  [390.0,
#   662.0,
#   0.3880508343732944,
#   8.0,
#   'Writing aid.',
#   ['Book/Non-fiction/Education', 'Writing tool.']],
#  [417.0,
#   669.0,
#   0.3898977420147243,
#   4.0,
#   'Musical education.',
#   ['Music history.', 'Music knowledge.']],
#  [668.0,
#   670.0,
#   0.3953088523527846,
#   10.0,
#   'Planning aid.',
#   ['Writing aid.', 'Strategy']],
#  [422.0,
#   671.0,
#   0.38999026540935133,
#   5.0,
#   'Education.',
#   ['Music book', 'Musical education.']],
#  [422.0,
#   671.0,
#   0.38999026540935133,
#   5.0,
#   'Education.',
#   ['Music book', 'Musical education.']],
#  [259.0,
#   357.0,
#   0.39071452856827354,
#   2.0,
#   'Adventure fiction.',
#   ['Book collection.', 'Fiction book: Verne.']],
#  [319.0,
#   370.0,
#   0.3910640143995622,
#   2.0,
#   'Teaching music.',
#   ['Book: Music Pedagogy (French)', 'Music teaching (group).']],
#  [673.0,
#   675.0,
#   0.43033970185573,
#   5.0,
#   'Thrilling stories.',
#   ['Adventure fiction.', 'Adventure fiction.']],
#  [209.0,
#   652.0,
#   0.39233436335360866,
#   3.0,
#   'Theory.',
#   ['Book - Freud - Philosophy', 'Geometry.']],
#  [676.0,
#   677.0,
#   0.3957558257230506,
#   6.0,
#   'Communication theories.',
#   ['Theory.', 'Language & Writing.']],
#  [672.0,
#   678.0,
#   0.3958476220909244,
#   9.0,
#   'Music education.',
#   ['Education.', 'Musical education.']],
#  [126.0,
#   679.0,
#   0.41418182518026586,
#   3.0,
#   'Note-taking efficiency.',
#   ['Note-taking caution', 'Note-taking productivity.']],
#  [233.0,
#   459.0,
#   0.3943751921810257,
#   2.0,
#   'Book genre.',
#   ['Natural history book', 'French literature (book)']],
#  [70.0,
#   78.0,
#   0.3952225479492272,
#   2.0,
#   'Advice categories.',
#   ['Self-help advice.', 'Book categories: practical and theoretical.']],
#  [64.0,
#   682.0,
#   0.4022415838286151,
#   11.0,
#   'Organizational tool.',
#   ['Note-taking method.', 'Planning aid.']],
#  [238.0,
#   683.0,
#   0.3999106205307512,
#   3.0,
#   'Digital text.',
#   ['Book (non-fiction)', 'Downloadable.']],
#  [676.0,
#   677.0,
#   0.3957558257230506,
#   6.0,
#   'Communication theories.',
#   ['Theory.', 'Language & Writing.']],
#  [472.0,
#   685.0,
#   0.401631737967855,
#   10.0,
#   'Musical knowledge.',
#   ['History of music.', 'Music education.']],
#  [680.0,
#   686.0,
#   0.40391044755878164,
#   4.0,
#   'Reading.',
#   ['Book genre.', 'Knowledge acquisition.']],
#  [638.0,
#   687.0,
#   0.410891211811474,
#   4.0,
#   'Numbers and words.',
#   ['Mathematics literature.', 'Mathematics book']],
#  [464.0,
#   688.0,
#   0.4126816480125852,
#   3.0,
#   'Mathematical analysis.',
#   ['Book on fractal geometry.', 'Book on mathematics']],
#  [433.0,
#   689.0,
#   0.3986561708755174,
#   4.0,
#   'Leisure activity.',
#   ['Shopping: Book', 'Analysis of literature.']],
#  [433.0,
#   689.0,
#   0.3986561708755174,
#   4.0,
#   'Leisure activity.',
#   ['Shopping: Book', 'Analysis of literature.']],
#  [76.0,
#   691.0,
#   0.3997071586116237,
#   5.0,
#   'Interpretation ability.',
#   ['Reading interpretation.', 'Interpretive skills.']],
#  [114.0,
#   692.0,
#   0.4050636776346802,
#   6.0,
#   'Reading comprehension.',
#   ['Types of Reading', 'Interpretation ability.']],
#  [356.0,
#   693.0,
#   0.40192047460951386,
#   4.0,
#   'Reading adventure.',
#   ['Book, Adventure.', 'Digital text.']],
#  [603.0,
#   694.0,
#   0.4291297663033201,
#   4.0,
#   'Coordination.',
#   ['Project management.', 'Digital platforms.']],
#  [381.0,
#   695.0,
#   0.4066799372709571,
#   4.0,
#   'French classics.',
#   ['Literature/classics.', 'Acquisition - Francophone.']],
#  [227.0,
#   656.0,
#   0.4010622933563719,
#   11.0,
#   'Narrative creation.',
#   ['Biography.', 'Creative storytelling.']],
#  [276.0,
#   697.0,
#   0.40275731002084414,
#   11.0,
#   'Musical literacy.',
#   ['Music book.', 'Musical knowledge.']],
#  [598.0,
#   698.0,
#   0.40556895146726607,
#   6.0,
#   'Escapist literature.',
#   ['Russian Fiction Books.', 'Reading adventure.']],
#  [64.0,
#   682.0,
#   0.4022415838286151,
#   11.0,
#   'Organizational tool.',
#   ['Note-taking method.', 'Planning aid.']],
#  [254.0,
#   700.0,
#   0.4052557954638044,
#   12.0,
#   'Musical notation.',
#   ['French music book.', 'Musical literacy.']],
#  [667.0,
#   701.0,
#   0.42787500722974553,
#   6.0,
#   'Words: Literacy promotion.',
#   ['Book sale.', 'Reading.']],
#  [234.0,
#   702.0,
#   0.40834351259625834,
#   3.0,
#   'Mathematical principles.',
#   ['Science.', 'Counting methods.']],
#  [82.0,
#   703.0,
#   0.4170767495051201,
#   7.0,
#   'Reading aid.',
#   ['Reading comprehension aid.', 'Reading comprehension.']],
#  [309.0,
#   704.0,
#   0.4068814209720856,
#   13.0,
#   'Brain activity.',
#   ['Book (neurology)', 'Musical notation.']],
#  [684.0,
#   705.0,
#   0.4066687737016216,
#   12.0,
#   'Escapism.',
#   ['Communication theories.', 'Escapist literature.']],
#  [87.0,
#   706.0,
#   0.43758561414021985,
#   3.0,
#   'Creative writing.',
#   ['Fiction advice.', 'Imagination']],
#  [684.0,
#   705.0,
#   0.4066687737016216,
#   12.0,
#   'Escapism.',
#   ['Communication theories.', 'Escapist literature.']],
#  [707.0,
#   708.0,
#   0.41211113376959163,
#   16.0,
#   'Fantasy literature.',
#   ['Escapism.', 'French classics.']],
#  [20.0,
#   709.0,
#   0.4913817058563016,
#   3.0,
#   'Visual interaction.',
#   ['AR devices', 'Virtual interfaces.']],
#  [340.0,
#   710.0,
#   0.40881110814865607,
#   14.0,
#   'Cognition and music.',
#   ['Book about music.', 'Brain activity.']],
#  [699.0,
#   711.0,
#   0.41250975076965846,
#   13.0,
#   'Organization strategy.',
#   ['Organizational tool.', 'Note-taking organization.']],
#  [572.0,
#   712.0,
#   0.45489020261566565,
#   3.0,
#   'Drilling expertise.',
#   ['Occupation: Mine Driver', 'Rock fragmentation.']],
#  [349.0,
#   713.0,
#   0.41069293669505813,
#   4.0,
#   'Mathematics concepts.',
#   ['Mathematics book.', 'Mathematical principles.']],
#  [442.0,
#   714.0,
#   0.4265845847207166,
#   15.0,
#   'Musical cognition.',
#   ['Biography, Jazz legend.', 'Cognition and music.']],
#  [302.0,
#   636.0,
#   0.4098754743082107,
#   27.0,
#   'None.',
#   ['Book edition.', 'Animals.']],
#  [349.0,
#   713.0,
#   0.41069293669505813,
#   4.0,
#   'Mathematics concepts.',
#   ['Mathematics book.', 'Mathematical principles.']],
#  [373.0,
#   717.0,
#   0.4120155138428328,
#   3.0,
#   'Cogito ergo sum.',
#   ['Book, Philosophy, Descartes.', 'Purchase.']],
#  [716.0,
#   718.0,
#   0.4169379647707478,
#   8.0,
#   'Number concepts.',
#   ['Mathematics concepts.', 'Numbers and words.']],
#  [352.0,
#   479.0,
#   0.4109447203961686,
#   2.0,
#   'Mathematics convention.',
#   ['Mathematical Congress.', 'Mathematics book.']],
#  [232.0,
#   374.0,
#   0.4111426286546779,
#   2.0,
#   'Technology.',
#   ['Book/Biography/Mathematics.', 'Book about art and technology.']],
#  [226.0,
#   328.0,
#   0.4114352702056332,
#   2.0,
#   'Language book translation.',
#   ['Book, Gracían', 'Book, Translation, French']],
#  [331.0,
#   467.0,
#   0.41161057494260933,
#   2.0,
#   'Cryptocurrency introduction.',
#   ['Book on cryptocurrency.', 'Blockchain primer']],
#  [373.0,
#   717.0,
#   0.4120155138428328,
#   3.0,
#   'Cogito ergo sum.',
#   ['Book, Philosophy, Descartes.', 'Purchase.']],
#  [723.0,
#   724.0,
#   0.41608271983578626,
#   19.0,
#   'Imagination and existence.',
#   ['Cogito ergo sum.', 'Fantasy literature.']],
#  [81.0,
#   725.0,
#   0.415857326980897,
#   14.0,
#   'Written organization.',
#   ['Note-taking method', 'Organization strategy.']],
#  [74.0,
#   85.0,
#   0.4125697162492948,
#   2.0,
#   'Language skills.',
#   ['Dictionary use.', 'Reading advice.']],
#  [354.0,
#   727.0,
#   0.41410047826711593,
#   4.0,
#   'Calculus.',
#   ['Book.', 'Mathematical analysis.']],
#  [152.0,
#   728.0,
#   0.46494223269874463,
#   4.0,
#   'Innovation within boundaries.',
#   ['Creativity under restrictions.', 'Digital representation.']],
#  [206.0,
#   428.0,
#   0.4139110822021865,
#   2.0,
#   'Joaquín Navarro.',
#   ['Book, author Joaquín Navarro.', 'Book, Author, Joaquín.']],
#  [419.0,
#   730.0,
#   0.41478417355407027,
#   5.0,
#   'Calculus.',
#   ['book/mathematics/Le Monde', 'Calculus.']],
#  [122.0,
#   731.0,
#   0.41774586958251225,
#   4.0,
#   'Efficient discovery.',
#   ['Discovery tool.', 'Note-taking efficiency.']],
#  [136.0,
#   732.0,
#   0.42750120704618205,
#   3.0,
#   'Recording space.',
#   ['Studio arrangement', 'Studio soundproofing']],
#  [419.0,
#   730.0,
#   0.41478417355407027,
#   5.0,
#   'Calculus.',
#   ['book/mathematics/Le Monde', 'Calculus.']],
#  [446.0,
#   639.0,
#   0.41506035109161155,
#   5.0,
#   'Words and terms.',
#   ['Fashion dictionary.', 'French language.']],
#  [81.0,
#   725.0,
#   0.415857326980897,
#   14.0,
#   'Written organization.',
#   ['Note-taking method', 'Organization strategy.']],
#  [389.0,
#   736.0,
#   0.41669084730819994,
#   20.0,
#   'Philosophical imagination.',
#   ['Literary philosophy.', 'Imagination and existence.']],
#  [420.0,
#   737.0,
#   0.41921729147417325,
#   21.0,
#   'French philosopher.',
#   ['Book - Saint Simon.', 'Philosophical imagination.']],
#  [332.0,
#   738.0,
#   0.418349615191904,
#   9.0,
#   'Numbers.',
#   ['Mathematics book.', 'Number concepts.']],
#  [735.0,
#   739.0,
#   0.42477761076256804,
#   21.0,
#   'Text formatting.',
#   ['Written organization.', 'Reading aid.']],
#  [75.0,
#   740.0,
#   0.4413798824879519,
#   3.0,
#   'Learning strategies.',
#   ['Education phases.', 'Study skills.']],
#  [719.0,
#   741.0,
#   0.43165809404217004,
#   4.0,
#   'Mathematics literature.',
#   ['Mathematics convention.', 'Mathematics book.']],
#  [122.0,
#   731.0,
#   0.41774586958251225,
#   4.0,
#   'Efficient discovery.',
#   ['Discovery tool.', 'Note-taking efficiency.']],
#  [733.0,
#   743.0,
#   0.42500818411169633,
#   14.0,
#   'Mathematics.',
#   ['Calculus.', 'Numbers.']],
#  [690.0,
#   744.0,
#   0.42263162471910926,
#   25.0,
#   'Thinking.',
#   ['Leisure activity.', 'French philosopher.']],
#  [248.0,
#   364.0,
#   0.4196577750144056,
#   2.0,
#   'Mathematics text.',
#   ['Math problem book.', 'Mathematics book.']],
#  [720.0,
#   746.0,
#   0.42167441985116333,
#   6.0,
#   'Digital access.',
#   ['Technology.', 'Information sources.']],
#  [305.0,
#   653.0,
#   0.4201347517366654,
#   3.0,
#   'Biography.',
#   ['Author: James Brown.', 'Life stories.']],
#  [279.0,
#   748.0,
#   0.42422954963543963,
#   7.0,
#   'Business education.',
#   ['Book on entrepreneurship.', 'Digital access.']],
#  [249.0,
#   749.0,
#   0.4240281727870857,
#   26.0,
#   'Inference.',
#   ['Book, Statistics, Lehmann.', 'Thinking.']],
#  [119.0,
#   750.0,
#   0.4243783212780006,
#   3.0,
#   'Note-taking strategies.',
#   ['Note-taking system.', 'Note-taking productivity.']],
#  [180.0,
#   633.0,
#   0.4237935070645278,
#   4.0,
#   'Underwater breathing mixtures.',
#   ['Mixed-gas diving.', 'Trimix.']],
#  [171.0,
#   752.0,
#   0.4780399381536066,
#   3.0,
#   'Investment criteria.',
#   ['VC selection', 'Startup resources.']],
#  [378.0,
#   753.0,
#   0.4241233533791832,
#   27.0,
#   'French literature.',
#   ["Book: Hugo's 1926.", 'Inference.']],
#  [441.0,
#   754.0,
#   0.4249041128801922,
#   28.0,
#   'Literature genre.',
#   ['Book, Stendhal', 'French literature.']],
#  [405.0,
#   755.0,
#   0.42719096895455044,
#   8.0,
#   'Technology.',
#   ['Book: Artificial Intelligence.', 'Business education.']],
#  [742.0,
#   756.0,
#   0.427574466133835,
#   7.0,
#   'Information management.',
#   ['Efficient discovery.', 'Note-taking strategies.']],
#  [681.0,
#   757.0,
#   0.4266852561602353,
#   23.0,
#   '"Formatting options"',
#   ['Advice categories.', 'Text formatting.']],
#  [475.0,
#   758.0,
#   0.4258080624739416,
#   29.0,
#   'Historical fiction.',
#   ['Book, fiction, French.', 'Literature genre.']],
#  [323.0,
#   759.0,
#   0.42512399804913986,
#   15.0,
#   'Problem-solving.',
#   ['Book, author', 'Mathematics.']],
#  [448.0,
#   760.0,
#   0.4267427672150749,
#   16.0,
#   'Mathematical problem-solving.',
#   ['Mathematics book.', 'Problem-solving.']],
#  [314.0,
#   761.0,
#   0.426549711634324,
#   30.0,
#   'France.',
#   ['French cuisine book.', 'Historical fiction.']],
#  [296.0,
#   310.0,
#   0.4258730294390538,
#   2.0,
#   'Innovators.',
#   ['Biography.', 'French innovators biography.']],
#  [314.0,
#   761.0,
#   0.426549711634324,
#   30.0,
#   'France.',
#   ['French cuisine book.', 'Historical fiction.']],
#  [301.0,
#   764.0,
#   0.4274793708797018,
#   16.0,
#   'Cognition / Understanding.',
#   ['Book; Literature; Non-fiction.', 'Musical cognition.']],
#  [162.0,
#   765.0,
#   0.42934024512446983,
#   24.0,
#   '"Visual layout"',
#   ['Note-taking technique.', '"Formatting options"']],
#  [763.0,
#   766.0,
#   0.42680869721706655,
#   46.0,
#   'Calculus.',
#   ['France.', 'Mathematical problem-solving.']],
#  [317.0,
#   767.0,
#   0.42684987105189165,
#   47.0,
#   'Abstraction.',
#   ['Art history.', 'Calculus.']],
#  [729.0,
#   768.0,
#   0.42704897579408124,
#   49.0,
#   'Artistic style.',
#   ['Joaquín Navarro.', 'Abstraction.']],
#  [416.0,
#   769.0,
#   0.42706489073652437,
#   50.0,
#   'French Rococo',
#   ['Mathematics history (in French)', 'Artistic style.']],
#  [696.0,
#   770.0,
#   0.42707687722917764,
#   61.0,
#   'Decorative art.',
#   ['Narrative creation.', 'French Rococo']],
#  [334.0,
#   771.0,
#   0.427579359849149,
#   62.0,
#   'French art.',
#   ['French Math Stories', 'Decorative art.']],
#  [405.0,
#   755.0,
#   0.42719096895455044,
#   8.0,
#   'Technology.',
#   ['Book: Artificial Intelligence.', 'Business education.']],
#  [301.0,
#   764.0,
#   0.4274793708797018,
#   16.0,
#   'Cognition / Understanding.',
#   ['Book; Literature; Non-fiction.', 'Musical cognition.']],
#  [136.0,
#   732.0,
#   0.42750120704618205,
#   3.0,
#   'Recording space.',
#   ['Studio arrangement', 'Studio soundproofing']],
#  [742.0,
#   756.0,
#   0.427574466133835,
#   7.0,
#   'Information management.',
#   ['Efficient discovery.', 'Note-taking strategies.']],
#  [334.0,
#   771.0,
#   0.427579359849149,
#   62.0,
#   'French art.',
#   ['French Math Stories', 'Decorative art.']],
#  [183.0,
#   777.0,
#   0.44152935893799594,
#   3.0,
#   'Underwater breathing.',
#   ['Diving equipment.', 'Nitrogen narcosis risk.']],
#  [399.0,
#   594.0,
#   0.42786448395325166,
#   3.0,
#   'Knowledge seekers.',
#   ['Book - Philosophy - Alchemy', 'Occultism.']],
#  [776.0,
#   779.0,
#   0.4286090119953941,
#   68.0,
#   'Culture appreciation.',
#   ['French art.', 'Words: Literacy promotion.']],
#  [502.0,
#   529.0,
#   0.42790145490256204,
#   2.0,
#   'Digital ownership.',
#   ['NFTs - unique collectibles',
#    'Category: Investments\nSubcategory: Digital Art\nKeyword: NFT']],
#  [778.0,
#   781.0,
#   0.4307293970844419,
#   71.0,
#   'Learning enthusiasts.',
#   ['Knowledge seekers.', 'Culture appreciation.']],
#  [527.0,
#   782.0,
#   0.4575315070654945,
#   5.0,
#   'Planning.',
#   ['Gardening plan', 'Coordination.']],
#  [65.0,
#   783.0,
#   0.4312110031069466,
#   25.0,
#   'Design principles.',
#   ['Programming principle.', '"Visual layout"']],
#  [673.0,
#   675.0,
#   0.43033970185573,
#   5.0,
#   'Thrilling stories.',
#   ['Adventure fiction.', 'Adventure fiction.']],
#  [207.0,
#   785.0,
#   0.4333238617624815,
#   4.0,
#   'Technology integration.',
#   ['Construction innovation.', 'STEM resources.']],
#  [466.0,
#   786.0,
#   0.4320394062668899,
#   72.0,
#   'Myths.',
#   ['Book - Mythology.', 'Learning enthusiasts.']],
#  [775.0,
#   787.0,
#   0.43161198922958144,
#   32.0,
#   'Organizational strategy.',
#   ['Information management.', 'Design principles.']],
#  [101.0,
#   651.0,
#   0.4314691833866965,
#   3.0,
#   'Expectation analysis.',
#   ['Book marketing rhetoric.', 'Criticism expectation.']],
#  [118.0,
#   789.0,
#   0.4339412434773616,
#   33.0,
#   'Writing strategy.',
#   ['Reading for writing skills.', 'Organizational strategy.']],
#  [719.0,
#   741.0,
#   0.43165809404217004,
#   4.0,
#   'Mathematics literature.',
#   ['Mathematics convention.', 'Mathematics book.']],
#  [790.0,
#   791.0,
#   0.4321902711069843,
#   76.0,
#   'Storytelling.',
#   ['Mathematics literature.', 'Myths.']],
#  [396.0,
#   792.0,
#   0.43254849971297143,
#   77.0,
#   'Narrative analysis.',
#   ['Book review.', 'Storytelling.']],
#  [773.0,
#   793.0,
#   0.4326963336108054,
#   93.0,
#   'Understanding cognition.',
#   ['Cognition / Understanding.', 'Narrative analysis.']],
#  [237.0,
#   794.0,
#   0.4327161661225828,
#   94.0,
#   'Learning about cognition.',
#   ['Paris Museums Guide.', 'Understanding cognition.']],
#  [289.0,
#   795.0,
#   0.4331512822734485,
#   95.0,
#   'Imagination development.',
#   ['Book, Fiction.', 'Learning about cognition.']],
#  [293.0,
#   796.0,
#   0.4333814840100679,
#   96.0,
#   'Creativity enhancement.',
#   ['Mythology characters.', 'Imagination development.']],
#  [772.0,
#   797.0,
#   0.4357122613909829,
#   12.0,
#   'Technology use.',
#   ['Technology.', 'Technology integration.']],
#  [674.0,
#   798.0,
#   0.4338023403277392,
#   98.0,
#   'Musical creativity.',
#   ['Teaching music.', 'Creativity enhancement.']],
#  [492.0,
#   799.0,
#   0.4413051750985074,
#   3.0,
#   'Smart connectivity.',
#   ['Smart thermostats.', 'Smart technology.']],
#  [745.0,
#   800.0,
#   0.4347127646607861,
#   100.0,
#   'Creativity.',
#   ['Mathematics text.', 'Musical creativity.']],
#  [118.0,
#   789.0,
#   0.4339412434773616,
#   33.0,
#   'Writing strategy.',
#   ['Reading for writing skills.', 'Organizational strategy.']],
#  [734.0,
#   802.0,
#   0.4350626754546274,
#   105.0,
#   ' Linguistic creativity.',
#   ['Words and terms.', 'Creativity.']],
#  [747.0,
#   803.0,
#   0.4361575344397096,
#   108.0,
#   'Expression of self.',
#   ['Biography.', ' Linguistic creativity.']],
#  [762.0,
#   804.0,
#   0.4379162799187426,
#   14.0,
#   'Creativity-driven adoption.',
#   ['Innovators.', 'Technology use.']],
#  [400.0,
#   805.0,
#   0.43751880931854104,
#   109.0,
#   'Self-expression through writing.',
#   ['Author: Joan Gómez.', 'Expression of self.']],
#  [457.0,
#   806.0,
#   0.4375512246372698,
#   110.0,
#   'Problem-solving.',
#   ['Mathematics.', 'Self-expression through writing.']],
#  [413.0,
#   807.0,
#   0.43794558648835297,
#   111.0,
#   'Exploration.',
#   ['Adventure, sailing.', 'Problem-solving.']],
#  [801.0,
#   808.0,
#   0.4427268546174202,
#   36.0,
#   'Writing process.',
#   ['Writing strategy.', 'Creative writing.']],
#  [762.0,
#   804.0,
#   0.4379162799187426,
#   14.0,
#   'Creativity-driven adoption.',
#   ['Innovators.', 'Technology use.']],
#  [458.0,
#   810.0,
#   0.43875791982079826,
#   112.0,
#   'Problem solving.',
#   ['Mathematics book.', 'Exploration.']],
#  [256.0,
#   811.0,
#   0.4391122873643682,
#   113.0,
#   'Puzzle solving.',
#   ['Author: Pere Grima', 'Problem solving.']],
#  [327.0,
#   812.0,
#   0.43919723840077324,
#   114.0,
#   'Problem-solving.',
#   ['Mathematics book.', 'Puzzle solving.']],
#  [634.0,
#   813.0,
#   0.4392035822943742,
#   116.0,
#   'Creativity.',
#   ['Music books.', 'Problem-solving.']],
#  [600.0,
#   814.0,
#   0.43952225729116984,
#   118.0,
#   'Language generation.',
#   ['Predictive text.', 'Creativity.']],
#  [198.0,
#   815.0,
#   0.43991405856720217,
#   119.0,
#   'Generations of music.',
#   ['Category: Music history', 'Language generation.']],
#  [784.0,
#   816.0,
#   0.4402687330881561,
#   124.0,
#   'Entertainment genre.',
#   ['Thrilling stories.', 'Generations of music.']],
#  [376.0,
#   817.0,
#   0.4404909091822698,
#   125.0,
#   'Books.',
#   ['book/editors/Various & Le Grand Livre Du Mois', 'Entertainment genre.']],
#  [291.0,
#   818.0,
#   0.44064929202611935,
#   126.0,
#   'Written works.',
#   ['Literature.', 'Books.']],
#  [251.0,
#   819.0,
#   0.44135380807574315,
#   127.0,
#   'Book authorship.',
#   ['Book, author Jacques Siron.', 'Written works.']],
#  [489.0,
#   820.0,
#   0.45825815950567794,
#   4.0,
#   'Connected surveillance.',
#   ['Affordable security cameras.', 'Smart connectivity.']],
#  [324.0,
#   821.0,
#   0.44197482327209325,
#   128.0,
#   'Writing process.',
#   ['Book - Mathematics - Editing', 'Book authorship.']],
#  [75.0,
#   740.0,
#   0.4413798824879519,
#   3.0,
#   'Learning strategies.',
#   ['Education phases.', 'Study skills.']],
#  [178.0,
#   823.0,
#   0.45599028629261706,
#   4.0,
#   'Breathing gas.',
#   ['Gas mixture.', 'Underwater breathing.']],
#  [201.0,
#   824.0,
#   0.4420404020027077,
#   129.0,
#   'French writing.',
#   ['Category: Books/French novels.', 'Writing process.']],
#  [257.0,
#   825.0,
#   0.44227375608500963,
#   130.0,
#   'French.',
#   ['Book / Durand / Music', 'French writing.']],
#  [715.0, 826.0, 0.4434504634690863, 157.0, 'Language.', ['None.', 'French.']],
#  [2.0,
#   827.0,
#   0.4447752651603763,
#   37.0,
#   'Language skills.',
#   ['Reading technique', 'Writing process.']],
#  [90.0,
#   160.0,
#   0.44283720649609587,
#   2.0,
#   'Concentration skill.',
#   ['Creating focus.', 'Productivity tip.']],
#  [292.0,
#   829.0,
#   0.44395071721974594,
#   158.0,
#   'Stories.',
#   ['Literature, historical fiction.', 'Language.']],
#  [809.0,
#   830.0,
#   0.4444714947806954,
#   172.0,
#   'Narrative innovation.',
#   ['Creativity-driven adoption.', 'Stories.']],
#  [383.0,
#   831.0,
#   0.4450780656586199,
#   173.0,
#   'Storytelling.',
#   ['Book, Literature, Fiction.', 'Narrative innovation.']],
#  [822.0,
#   832.0,
#   0.4467650034457028,
#   40.0,
#   'Academic success.',
#   ['Learning strategies.', 'Language skills.']],
#  [341.0,
#   833.0,
#   0.44546709507419885,
#   174.0,
#   'Communication method.',
#   ['Book on economics.', 'Storytelling.']],
#  [361.0,
#   834.0,
#   0.4455092328054729,
#   175.0,
#   'Symbols.',
#   ['Mathematics/ Electricity Theory.', 'Communication method.']],
#  [455.0,
#   835.0,
#   0.4462727891812967,
#   176.0,
#   'Math symbols.',
#   ['Math book (category) in French (language).', 'Symbols.']],
#  [345.0,
#   365.0,
#   0.44555440111623734,
#   2.0,
#   '"Book content"',
#   ['Book on life.', 'Book, Mathematics.']],
#  [476.0,
#   837.0,
#   0.4466101687953138,
#   177.0,
#   'Publication date.',
#   ['Book/Edition - Richard Brown/France Loisirs - Released 05/2013',
#    'Math symbols.']],
#  [330.0,
#   838.0,
#   0.44700228618238574,
#   178.0,
#   'Time stamp.',
#   ['Product: Book.', 'Publication date.']],
#  [95.0,
#   839.0,
#   0.4472647801515438,
#   41.0,
#   'Comprehension skill.',
#   ['Reading technique.', 'Academic success.']],
#  [200.0,
#   840.0,
#   0.4478466242225291,
#   179.0,
#   'Language evolution',
#   ['General history / Leather / Middle French.', 'Time stamp.']],
#  [91.0,
#   841.0,
#   0.4487904928756518,
#   42.0,
#   'Reading understanding.',
#   ['Literary analysis.', 'Comprehension skill.']],
#  [212.0,
#   443.0,
#   0.4473711003566786,
#   2.0,
#   'Self-improvement.',
#   ['Self-help book.', 'Self-help book.']],
#  [283.0,
#   843.0,
#   0.4483922932250218,
#   180.0,
#   'Writing history.',
#   ['Book, Author, Raúl', 'Language evolution']],
#  [517.0,
#   844.0,
#   0.4628552242359018,
#   3.0,
#   'Meeting places',
#   ['Music venues in France.', 'Socializing spots.']],
#  [12.0,
#   13.0,
#   0.44836011123461833,
#   2.0,
#   'Reading skill.',
#   ['Speed Reading Guide.', 'Reading technique.']],
#  [474.0,
#   846.0,
#   0.4487275952192462,
#   181.0,
#   'Writing.',
#   ['book, fiction, French', 'Writing history.']],
#  [493.0,
#   495.0,
#   0.4486578762171873,
#   2.0,
#   '"Home automation"',
#   ['IoT lighting control.', 'Smart home device']],
#  [224.0,
#   848.0,
#   0.44878483906201333,
#   182.0,
#   'Creative expression.',
#   ['Music industry guide.', 'Writing.']],
#  [721.0,
#   849.0,
#   0.4494490569492753,
#   184.0,
#   'Translation creativity.',
#   ['Language book translation.', 'Creative expression.']],
#  [117.0,
#   850.0,
#   0.45163171592348866,
#   43.0,
#   'Comprehension skills.',
#   ['Abstract thinking.', 'Reading understanding.']],
#  [322.0,
#   851.0,
#   0.44966544262454994,
#   185.0,
#   'Interpretive skill.',
#   ['French literature.', 'Translation creativity.']],
#  [311.0,
#   852.0,
#   0.4498078793855461,
#   186.0,
#   'Astrophysics education.',
#   ['Book - Trinh Xuan Thuan - Cosmos/Lotus.', 'Interpretive skill.']],
#  [412.0,
#   853.0,
#   0.45009467980037854,
#   187.0,
#   'None apparent.',
#   ['Cryptography reference.', 'Astrophysics education.']],
#  [392.0,
#   854.0,
#   0.450720785659852,
#   188.0,
#   'Gender and numbers.',
#   ['Women and mathematics.', 'None apparent.']],
#  [410.0,
#   855.0,
#   0.45099481814763465,
#   189.0,
#   'Societal expectations.',
#   ['Play.', 'Gender and numbers.']],
#  [406.0,
#   856.0,
#   0.45171336323301664,
#   190.0,
#   'Satire.',
#   ['Book; Comedy; Molière.', 'Societal expectations.']],
#  [580.0,
#   857.0,
#   0.4761074679699374,
#   4.0,
#   'Secondhand attire.',
#   ['Clothing, Used.', 'Adjectives.']],
#  [96.0,
#   858.0,
#   0.4526884148080207,
#   44.0,
#   'Reading ability.',
#   ['Education and retention.', 'Comprehension skills.']],
#  [836.0,
#   859.0,
#   0.45345949432136745,
#   192.0,
#   'Humorous literature.',
#   ['"Book content"', 'Satire.']],
#  [55.0,
#   860.0,
#   0.47828797218123936,
#   3.0,
#   'Investment advice.',
#   ['"Current investments list"', 'Financial guidance.']],
#  [29.0,
#   861.0,
#   0.5600526927703389,
#   3.0,
#   'Reggae',
#   ['Music genre: Reggae pattern', 'Jamaican music']],
#  [128.0,
#   862.0,
#   0.46170268702473866,
#   45.0,
#   'Cognitive abilities.',
#   ['Intelligence traits', 'Reading ability.']],
#  [205.0,
#   863.0,
#   0.4537413512056599,
#   193.0,
#   'Self-improvement through humor.',
#   ['Category: Personal Development.', 'Humorous literature.']],
#  [239.0,
#   864.0,
#   0.45477874748119673,
#   194.0,
#   'Personal growth.',
#   ['Book on finance.', 'Self-improvement through humor.']],
#  [437.0,
#   865.0,
#   0.4583145907675848,
#   195.0,
#   'Self-help book.',
#   ['Publication: Book (editors, date, and release information)',
#    'Personal growth.']],
#  [559.0,
#   866.0,
#   0.4993458857602954,
#   4.0,
#   'Learning skills.',
#   ['French verbs list', 'Drilling expertise.']],
#  [751.0,
#   867.0,
#   0.4579887480240797,
#   8.0,
#   'Respiratory gases.',
#   ['Underwater breathing mixtures.', 'Breathing gas.']],
#  [486.0,
#   487.0,
#   0.4575289216941334,
#   2.0,
#   'Smart home control.',
#   ['Smart speakers.', 'Smart device hub.']],
#  [527.0,
#   782.0,
#   0.4575315070654945,
#   5.0,
#   'Planning.',
#   ['Gardening plan', 'Coordination.']],
#  [184.0,
#   870.0,
#   0.4737157032161866,
#   9.0,
#   'None.',
#   ['Water sports / Educational / Exciting', 'Respiratory gases.']],
#  [847.0,
#   871.0,
#   0.46163321285160386,
#   6.0,
#   'Smart security.',
#   ['"Home automation"', 'Connected surveillance.']],
#  [452.0,
#   872.0,
#   0.4586638822713108,
#   196.0,
#   'Improvement culture.',
#   ['Egyptian civilization.', 'Self-help book.']],
#  [258.0,
#   873.0,
#   0.4588595527077656,
#   197.0,
#   'Writing style.',
#   ['Book, 1925, Henri Béraud.', 'Improvement culture.']],
#  [299.0,
#   874.0,
#   0.4605924288658,
#   198.0,
#   'Structure.',
#   ['Book about architecture.', 'Writing style.']],
#  [478.0,
#   660.0,
#   0.4592451451365257,
#   3.0,
#   'Leadership perspective.',
#   ['Book on leadership.', 'Leadership belief.']],
#  [355.0,
#   876.0,
#   0.4605957399080305,
#   199.0,
#   'Exchange.',
#   ['Transaction: Gift book.', 'Structure.']],
#  [619.0,
#   877.0,
#   0.46168735709161696,
#   201.0,
#   '"Information sharing"',
#   ['Books.', 'Exchange.']],
#  [490.0,
#   878.0,
#   0.4701985918218727,
#   7.0,
#   'Smart technology.',
#   ['Smart gardening devices', 'Smart security.']],
#  [384.0,
#   879.0,
#   0.46212717285492727,
#   202.0,
#   'Publication announcement.',
#   ['Book release.', '"Information sharing"']],
#  [84.0,
#   880.0,
#   0.46228802658498197,
#   46.0,
#   'Learning skills.',
#   ['Categorization: Teaching.', 'Cognitive abilities.']],
#  [842.0,
#   881.0,
#   0.4623546491782921,
#   204.0,
#   'Personal growth.',
#   ['Self-improvement.', 'Publication announcement.']],
#  [525.0,
#   882.0,
#   0.46478110220239066,
#   47.0,
#   'Skill development.',
#   ['Idea enthusiast.', 'Learning skills.']],
#  [270.0,
#   883.0,
#   0.4633968654609137,
#   205.0,
#   'Language learning.',
#   ['French play translation.', 'Personal growth.']],
#  [510.0,
#   884.0,
#   0.47891166540486074,
#   3.0,
#   'Knowledge and ethics.',
#   ['Philosophy: Morality.', 'Epistemology']],
#  [45.0,
#   885.0,
#   0.5226015121090175,
#   4.0,
#   'Social interaction spaces.',
#   ['Inspirational third places', 'Meeting places']],
#  [235.0,
#   886.0,
#   0.46340249302385506,
#   206.0,
#   'Learning.',
#   ['Book, Musicology, History.', 'Language learning.']],
#  [240.0,
#   887.0,
#   0.46436231923553817,
#   207.0,
#   'Knowledge acquisition.',
#   ['Book - Philosophy', 'Learning.']],
#  [657.0,
#   888.0,
#   0.4648551349649359,
#   209.0,
#   'Intellectual skills.',
#   ['Music Theory.', 'Knowledge acquisition.']],
#  [116.0,
#   889.0,
#   0.4658647849886599,
#   48.0,
#   'Reading skills.',
#   ['Analytical reading strategy.', 'Skill development.']],
#  [208.0,
#   890.0,
#   0.46562758214808686,
#   210.0,
#   'Self-improvement.',
#   ['Book - Olivier Roland', 'Intellectual skills.']],
#  [173.0,
#   891.0,
#   0.5342234366382616,
#   3.0,
#   'Video equipment.',
#   ['Outdoor videography gear.', 'Video creation tools.']],
#  [156.0,
#   892.0,
#   0.4922178036718086,
#   5.0,
#   'Creative innovation.',
#   ['Creative process techniques.', 'Innovation within boundaries.']],
#  [7.0,
#   8.0,
#   0.46528164457915266,
#   2.0,
#   'Reading assessment.',
#   ['Book Re-Reading.', 'Reading evaluation.']],
#  [294.0,
#   894.0,
#   0.4683617760116808,
#   211.0,
#   'Reading improvement.',
#   ['Book purchase from Le Monde.', 'Self-improvement.']],
#  [124.0,
#   895.0,
#   0.4679610935840361,
#   49.0,
#   'Critical thinking.',
#   ['Syntopical writing.', 'Reading skills.']],
#  [41.0,
#   896.0,
#   0.5546127503242287,
#   3.0,
#   'Electronics.',
#   ['Computer component.', 'Circuit design.']],
#  [548.0,
#   897.0,
#   0.5009232498267167,
#   3.0,
#   'Underwater exploration.',
#   ['Scuba destinations.', 'Adventure-seeking.']],
#  [9.0,
#   898.0,
#   0.47170289613105404,
#   50.0,
#   'Comparative thinking.',
#   ['Reading level: Syntopical. \nSubject focus: Comparative analysis.',
#    'Critical thinking.']],
#  [280.0,
#   899.0,
#   0.4692185813313752,
#   212.0,
#   'Literacy enhancement.',
#   ['Book/biography/business.', 'Reading improvement.']],
#  [654.0,
#   900.0,
#   0.47164863125475376,
#   4.0,
#   'Online shopping.',
#   ['Programming language.', 'Book buying.']],
#  [403.0,
#   901.0,
#   0.470313459219292,
#   213.0,
#   'Self-improvement.',
#   ['Title: "The Power of Now"\nCategory: Self-help book\nPublisher: J\'ai Lu Bien être\nRelease date: 03/2017\nPrice: 5.9€\nLength: 121 pages.',
#    'Literacy enhancement.']],
#  [488.0,
#   902.0,
#   0.4741565338144415,
#   8.0,
#   'Smart devices.',
#   ['Smart doorbells.', 'Smart technology.']],
#  [287.0,
#   903.0,
#   0.4704878286755507,
#   214.0,
#   'Personal growth.',
#   ['Autobiographical, Coming of Age.', 'Self-improvement.']],
#  [483.0,
#   904.0,
#   0.47847429133442265,
#   3.0,
#   'Ownership of items.',
#   ['Personal library.', 'Collectibles investment.']],
#  [295.0,
#   905.0,
#   0.47075875795878375,
#   215.0,
#   'Tragedy.',
#   ['Book, Racine, Drama.', 'Personal growth.']],
#  [382.0,
#   906.0,
#   0.4708851857537782,
#   216.0,
#   'None.',
#   ['Astronomy book.', 'Tragedy.']],
#  [271.0,
#   907.0,
#   0.4709187090942931,
#   217.0,
#   'None.',
#   ['Publication, Construction, Trends.', 'None.']],
#  [453.0,
#   908.0,
#   0.4711400333028232,
#   218.0,
#   'Informational.',
#   ['Book, self-help.', 'None.']],
#  [304.0,
#   909.0,
#   0.4713408659809379,
#   219.0,
#   'Brain knowledge.',
#   ['Book on neuroscience.', 'Informational.']],
#  [213.0,
#   910.0,
#   0.47251415821180154,
#   220.0,
#   'Information source.',
#   ['Book - Business', 'Brain knowledge.']],
#  [409.0,
#   911.0,
#   0.47623823114321207,
#   5.0,
#   'Digital media.',
#   ['E-book, programming.', 'Online shopping.']],
#  [6.0,
#   912.0,
#   0.47318526832545255,
#   51.0,
#   'Literacy skills.',
#   ['Basic reading level.', 'Comparative thinking.']],
#  [261.0,
#   913.0,
#   0.4730491830501139,
#   221.0,
#   'Knowledge source.',
#   ['Book - Economics - Galbraith', 'Information source.']],
#  [372.0,
#   914.0,
#   0.47373648654374134,
#   222.0,
#   'Information acquisition.',
#   ["Hacker's confession.", 'Knowledge source.']],
#  [3.0,
#   915.0,
#   0.47516943604408834,
#   52.0,
#   'Cognitive abilities.',
#   ['Philosophy styles.', 'Literacy skills.']],
#  [546.0,
#   916.0,
#   0.4963061062995065,
#   3.0,
#   'Island exploration.',
#   ['Geography/Oceania.', 'Island diving.']],
#  [177.0,
#   917.0,
#   0.5217754475096384,
#   10.0,
#   'Measurement.',
#   ['Gas pressure measurement.', 'None.']],
#  [348.0,
#   918.0,
#   0.47389766707772185,
#   223.0,
#   'Communication abilities.',
#   ['Influencing skills.', 'Information acquisition.']],
#  [268.0,
#   919.0,
#   0.47524628873399044,
#   224.0,
#   'Writing skills.',
#   ['Book, Fiction, Orwell.', 'Communication abilities.']],
#  [491.0,
#   920.0,
#   0.4754013977686578,
#   9.0,
#   'Connectivity.',
#   ['Smart locks – Convenience/Security', 'Smart devices.']],
#  [726.0,
#   921.0,
#   0.4756774679884036,
#   54.0,
#   'Mental processing.',
#   ['Language skills.', 'Cognitive abilities.']],
#  [371.0,
#   922.0,
#   0.47602911090182337,
#   225.0,
#   'Expression through words.',
#   ['Rock music history.', 'Writing skills.']],
#  [868.0,
#   923.0,
#   0.4768653372042309,
#   11.0,
#   'Automation.',
#   ['Smart home control.', 'Connectivity.']],
#  [11.0,
#   924.0,
#   0.47747775810346704,
#   55.0,
#   'Information processing.',
#   ['Truth-seeking texts.', 'Mental processing.']],
#  [339.0,
#   925.0,
#   0.4765934785922736,
#   226.0,
#   'Written communication.',
#   ['Mathematics book.', 'Expression through words.']],
#  [565.0,
#   926.0,
#   0.48792707128370405,
#   5.0,
#   'Secondhand language.',
#   ['Language translation.', 'Secondhand attire.']],
#  [409.0,
#   911.0,
#   0.47623823114321207,
#   5.0,
#   'Digital media.',
#   ['E-book, programming.', 'Online shopping.']],
#  [267.0,
#   928.0,
#   0.4769602152146446,
#   227.0,
#   'Written expression.',
#   ['Language pleasure.', 'Written communication.']],
#  [485.0,
#   929.0,
#   0.507720709479219,
#   12.0,
#   'Connections.',
#   ['Brands and devices.', 'Automation.']],
#  [927.0,
#   930.0,
#   0.47796580663570276,
#   232.0,
#   'Communication technology.',
#   ['Digital media.', 'Written expression.']],
#  [869.0,
#   931.0,
#   0.4807210288026008,
#   60.0,
#   'Organization.',
#   ['Planning.', 'Information processing.']],
#  [223.0,
#   250.0,
#   0.4777096337358427,
#   2.0,
#   'Storytelling.',
#   ['Book introduction.', 'Fiction/Novel/Series']],
#  [465.0,
#   933.0,
#   0.47859743388076387,
#   233.0,
#   'Information exchange.',
#   ['Book, Economics.', 'Communication technology.']],
#  [170.0,
#   934.0,
#   0.5194483156915903,
#   4.0,
#   'Decision making.',
#   ['Information gathering.', 'Investment criteria.']],
#  [54.0,
#   935.0,
#   0.4851559736029226,
#   4.0,
#   'Financial preparation.',
#   ['Personal finance/emergency fund.', 'Investment advice.']],
#  [484.0,
#   936.0,
#   0.4926996333601261,
#   4.0,
#   'Personal belongings.',
#   ['Books that influenced.', 'Ownership of items.']],
#  [449.0,
#   937.0,
#   0.47861487570964734,
#   234.0,
#   'Knowledge acquisition.',
#   ['Botany book.', 'Information exchange.']],
#  [362.0,
#   938.0,
#   0.478835210971047,
#   235.0,
#   'Book purchase.',
#   ['Second-hand book, 150€, Montpellier.', 'Knowledge acquisition.']],
#  [275.0,
#   939.0,
#   0.4796653715946409,
#   236.0,
#   'Knowledge acquisition.',
#   ['Book - Philosophy.', 'Book purchase.']],
#  [509.0,
#   940.0,
#   0.5022709823502272,
#   4.0,
#   'Power-seeking knowledge.',
#   ['Philosophy concept: will to power.', 'Knowledge and ethics.']],
#  [286.0,
#   941.0,
#   0.48248260947341576,
#   237.0,
#   'Information source.',
#   ['London guidebook.', 'Knowledge acquisition.']],
#  [103.0,
#   942.0,
#   0.48262804764832606,
#   61.0,
#   'Information management.',
#   ['Note storage strategies.', 'Organization.']],
#  [326.0,
#   943.0,
#   0.4844182951307043,
#   238.0,
#   'Knowledge.',
#   ['Book - Computer Science/Technology.', 'Information source.']],
#  [108.0,
#   944.0,
#   0.48279386978420824,
#   62.0,
#   'Decision-making.',
#   ['Problem-solving trade-offs', 'Information management.']],
#  [788.0,
#   945.0,
#   0.4831674534893982,
#   65.0,
#   'Prediction evaluation.',
#   ['Expectation analysis.', 'Decision-making.']],
#  [592.0,
#   946.0,
#   0.4835073751312413,
#   66.0,
#   'Cognitive processes.',
#   ['Memory aid through writing.', 'Prediction evaluation.']],
#  [845.0,
#   947.0,
#   0.48434683516525334,
#   68.0,
#   'Mental ability.',
#   ['Reading skill.', 'Cognitive processes.']],
#  [499.0,
#   948.0,
#   0.5035524991992554,
#   3.0,
#   'Technology.',
#   ['IoT trend: smart homes.', 'Digital music creation.']],
#  [100.0,
#   949.0,
#   0.4868403021797702,
#   69.0,
#   'Cognition.',
#   ['Nonlinear learning graph.', 'Mental ability.']],
#  [195.0,
#   950.0,
#   0.48518287660169923,
#   239.0,
#   '"Scuba guide knowledge"',
#   ['Guidebook/French/Scuba diving', 'Knowledge.']],
#  [54.0,
#   935.0,
#   0.4851559736029226,
#   4.0,
#   'Financial preparation.',
#   ['Personal finance/emergency fund.', 'Investment advice.']],
#  [236.0,
#   952.0,
#   0.48623724570245735,
#   240.0,
#   'Language, Diving.',
#   ['French book.', '"Scuba guide knowledge"']],
#  [350.0,
#   953.0,
#   0.48637827478142476,
#   241.0,
#   'Learning.',
#   ['Product: Book.', 'Language, Diving.']],
#  [308.0,
#   954.0,
#   0.48645953547726,
#   242.0,
#   'March publication.',
#   ['Book - Edited/Released - 03/2017.', 'Learning.']],
#  [375.0,
#   955.0,
#   0.48854506878642423,
#   243.0,
#   'Internet safety.',
#   ['Cybersecurity.', 'March publication.']],
#  [77.0,
#   956.0,
#   0.48830333209297144,
#   70.0,
#   'Mental processes.',
#   ['Problem-solving.', 'Cognition.']],
#  [51.0,
#   503.0,
#   0.4872459909656048,
#   2.0,
#   'Cryptocurrency trading',
#   ['Cryptocurrency education', 'Cryptocurrency exchanges']],
#  [581.0,
#   958.0,
#   0.5012223215888388,
#   6.0,
#   'Interpretation.',
#   ['Translation / Language.', 'Secondhand language.']],
#  [514.0,
#   959.0,
#   0.4920721712196972,
#   71.0,
#   'Information processing.',
#   ['Contact information.', 'Mental processes.']],
#  [722.0,
#   960.0,
#   0.4888553324716288,
#   245.0,
#   'Digital security.',
#   ['Cryptocurrency introduction.', 'Internet safety.']],
#  [414.0,
#   961.0,
#   0.4924715679991432,
#   246.0,
#   'Online transactions.',
#   ['Ebook purchase.', 'Digital security.']],
#  [22.0,
#   962.0,
#   0.5139569960740107,
#   4.0,
#   'Virtual immersion.',
#   ['augmented reality', 'Visual interaction.']],
#  [123.0,
#   963.0,
#   0.4928865368872427,
#   72.0,
#   'Creativity process.',
#   ['Idea generation strategy.', 'Information processing.']],
#  [541.0,
#   964.0,
#   0.5078038572084128,
#   6.0,
#   'Productivity techniques.',
#   ['Time Management Tip.', 'Creative innovation.']],
#  [411.0,
#   965.0,
#   0.49321095049350683,
#   247.0,
#   'Unusual purchases.',
#   ['Bizarre books.', 'Online transactions.']],
#  [484.0,
#   936.0,
#   0.4926996333601261,
#   4.0,
#   'Personal belongings.',
#   ['Books that influenced.', 'Ownership of items.']],
#  [893.0,
#   967.0,
#   0.49747235430763886,
#   74.0,
#   'Evaluation/Analysis.',
#   ['Reading assessment.', 'Creativity process.']],
#  [461.0,
#   968.0,
#   0.4955507688127103,
#   248.0,
#   'Risk-taking.',
#   ['Business strategy.', 'Unusual purchases.']],
#  [560.0,
#   969.0,
#   0.5075730820914583,
#   3.0,
#   'Negative descriptions.',
#   ['French adjective.', 'Evil words.']],
#  [243.0,
#   601.0,
#   0.4949923818620001,
#   3.0,
#   'Words and information',
#   ['Book - Bernard Werber - Encyclopedia', 'Reference material.']],
#  [970.0,
#   971.0,
#   0.4962914278256395,
#   251.0,
#   'Communication.',
#   ['Words and information', 'Risk-taking.']],
#  [439.0,
#   972.0,
#   0.49672023418251804,
#   252.0,
#   'Writing system.',
#   ['Hebrew religious text.', 'Communication.']],
#  [546.0,
#   916.0,
#   0.4963061062995065,
#   3.0,
#   'Island exploration.',
#   ['Geography/Oceania.', 'Island diving.']],
#  [217.0,
#   974.0,
#   0.4980392341241967,
#   253.0,
#   'Textual content.',
#   ['Mathematics book.', 'Writing system.']],
#  [542.0,
#   975.0,
#   0.5002752230629941,
#   75.0,
#   'Cognitive function.',
#   ['Memory strategy', 'Evaluation/Analysis.']],
#  [358.0,
#   976.0,
#   0.5003002299569184,
#   254.0,
#   'Written evaluation.',
#   ['Book review.', 'Textual content.']],
#  [86.0,
#   99.0,
#   0.4982321498813249,
#   2.0,
#   'Information seekers.',
#   ['Art collectors.', 'Library preference.']],
#  [574.0,
#   978.0,
#   0.500368492933699,
#   5.0,
#   'None.',
#   ['French coal quality', 'Learning skills.']],
#  [557.0,
#   577.0,
#   0.49949568947418443,
#   2.0,
#   'Polysemous French words.',
#   ['French vocabulary', 'French word - multiple meanings']],
#  [150.0,
#   980.0,
#   0.5007261994795246,
#   76.0,
#   'Memory aid.',
#   ['Note-taking tools.', 'Cognitive function.']],
#  [203.0,
#   981.0,
#   0.5010742761148533,
#   255.0,
#   'Written analysis.',
#   ['French Rhetoric (paperback)', 'Written evaluation.']],
#  [555.0,
#   982.0,
#   0.5102623118659756,
#   6.0,
#   'Task tracking.',
#   ['Work management.', 'None.']],
#  [98.0,
#   983.0,
#   0.5030512187265137,
#   77.0,
#   'Memory improvement.',
#   ['Memory enhancement tips.', 'Memory aid.']],
#  [548.0,
#   897.0,
#   0.5009232498267167,
#   3.0,
#   'Underwater exploration.',
#   ['Scuba destinations.', 'Adventure-seeking.']],
#  [932.0,
#   985.0,
#   0.502522893937562,
#   257.0,
#   'Interpretation.',
#   ['Storytelling.', 'Written analysis.']],
#  [554.0,
#   986.0,
#   0.5030426160891248,
#   7.0,
#   'Word meanings.',
#   ['Vocabulary definition', 'Interpretation.']],
#  [512.0,
#   987.0,
#   0.5114218663590059,
#   5.0,
#   'Epistemology quest.',
#   ['Philosophy concept.', 'Power-seeking knowledge.']],
#  [482.0,
#   988.0,
#   0.5026927582032709,
#   258.0,
#   'Textual analysis.',
# ...
#   2.0,
#   'Coding principles.',
#   ['Design principles.', 'Ruby programming example.']],
#  [169.0,
#   1059.0,
#   0.5404355721780799,
#   6.0,
#   'Presentations.',
#   ['Pitch decks.', 'Business decisions.']],
#  [545.0,
#   1060.0,
#   0.5296004447377508,
#   4.0,
#   'Personal development.',
#   ['Relationship building advice.', 'Self-improvement.']],
#  [545.0,
#   1060.0,
#   0.5296004447377508,
#   4.0,
#   'Personal development.',
#   ['Relationship building advice.', 'Self-improvement.']],
#  [575.0,
#   1062.0,
#   0.5361684078839932,
#   29.0,
#   'Descriptions of food.',
#   ['French vocabulary.', 'food textures.']],
#  [112.0,
#   1063.0,
#   0.5309615095553564,
#   375.0,
#   'Improved efficiency.',
#   ['Reading techniques.', 'Productivity aid.']],
#  [147.0,
#   1064.0,
#   0.5605966149716729,
#   3.0,
#   'Technology knowledge.',
#   ['Computer science concept.', 'Computing skills.']],
#  [505.0,
#   508.0,
#   0.5307642550588502,
#   2.0,
#   'Design synthesis.',
#   ['Art-engineering synthesis', 'Documentary on architecture.']],
#  [40.0,
#   142.0,
#   0.5308637524350025,
#   2.0,
#   'Digital signal processing',
#   ['Technology - DSP chip', 'Audio interface features.']],
#  [219.0,
#   1067.0,
#   0.5310999302397418,
#   376.0,
#   'Optimization.',
#   ['Music strategy guide.', 'Improved efficiency.']],
#  [436.0,
#   1068.0,
#   0.5316780828197648,
#   377.0,
#   'Writing optimization.',
#   ['Literature (Georges Sand)', 'Optimization.']],
#  [16.0,
#   1069.0,
#   0.532806701097239,
#   378.0,
#   'Textual analysis improvement.',
#   ['Reading analysis summary.', 'Writing optimization.']],
#  [130.0,
#   1024.0,
#   0.5324423549611508,
#   17.0,
#   'Technology',
#   ['Electronics education', 'Smart homes.']],
#  [402.0,
#   1071.0,
#   0.534151076290733,
#   379.0,
#   'Writing improvement.',
#   ['Music memoir.', 'Textual analysis improvement.']],
#  [52.0,
#   1072.0,
#   0.5352151902606197,
#   9.0,
#   'Money management.',
#   ['Financial products.', 'Financial investing.']],
#  [561.0,
#   573.0,
#   0.5336577250695862,
#   2.0,
#   'Vertical structures.',
#   ['Translation: Mobile wooden towers', 'Church nave.']],
#  [93.0,
#   1074.0,
#   0.5379585329171683,
#   380.0,
#   'Self-improvement.',
#   ['Mental growth unlimited.', 'Writing improvement.']],
#  [530.0,
#   1075.0,
#   0.5351047512121648,
#   4.0,
#   'Underwater tools.',
#   ['Scuba diving equipment.', 'Video equipment.']],
#  [25.0,
#   1076.0,
#   0.5360472856100591,
#   5.0,
#   'Filming techniques.',
#   ['YouTube video tips', 'Underwater tools.']],
#  [780.0,
#   1077.0,
#   0.5406309790668393,
#   11.0,
#   'Asset control.',
#   ['Digital ownership.', 'Money management.']],
#  [28.0,
#   1078.0,
#   0.5414813574856863,
#   4.0,
#   'Structure.',
#   ['Music theory', 'Organization structure.']],
#  [1044.0,
#   1079.0,
#   0.5388081773094466,
#   15.0,
#   'Capturing data.',
#   ['Measurement.', 'Filming techniques.']],
#  [552.0,
#   1080.0,
#   0.5389342831645848,
#   30.0,
#   'Word meanings.',
#   ['Vocabulary: Definition.', 'Descriptions of food.']],
#  [1033.0,
#   1081.0,
#   0.5381904907336118,
#   382.0,
#   'Funding.',
#   ['Crowdfunding', 'Self-improvement.']],
#  [110.0,
#   1082.0,
#   0.5385073985935418,
#   383.0,
#   'Education funding.',
#   ['Reading comprehension guide', 'Funding.']],
#  [973.0,
#   1083.0,
#   0.5405962561551458,
#   386.0,
#   'Exploration funding.',
#   ['Island exploration.', 'Education funding.']],
#  [181.0,
#   1084.0,
#   0.5559315914592953,
#   16.0,
#   'Oxygen monitoring.',
#   ['Health condition: Hyperoxia.', 'Capturing data.']],
#  [1073.0,
#   1085.0,
#   0.540106598948309,
#   32.0,
#   'Language analysis.',
#   ['Vertical structures.', 'Word meanings.']],
#  [584.0,
#   1086.0,
#   0.5414061387099867,
#   3.0,
#   'Goal-oriented approach.',
#   ['Task achievement strategy.', 'Behavior change.']],
#  [1073.0,
#   1085.0,
#   0.540106598948309,
#   32.0,
#   'Language analysis.',
#   ['Vertical structures.', 'Word meanings.']],
#  [169.0,
#   1059.0,
#   0.5404355721780799,
#   6.0,
#   'Presentations.',
#   ['Pitch decks.', 'Business decisions.']],
#  [1005.0,
#   1089.0,
#   0.5426307993463414,
#   392.0,
#   'Efficiency funding.',
#   ['Productivity techniques.', 'Exploration funding.']],
#  [780.0,
#   1077.0,
#   0.5406309790668393,
#   11.0,
#   'Asset control.',
#   ['Digital ownership.', 'Money management.']],
#  [584.0,
#   1086.0,
#   0.5414061387099867,
#   3.0,
#   'Goal-oriented approach.',
#   ['Task achievement strategy.', 'Behavior change.']],
#  [189.0,
#   1092.0,
#   0.5745376501801973,
#   5.0,
#   'Musical arrangements.',
#   ['Music covers learned.', 'Structure.']],
#  [59.0,
#   1093.0,
#   0.5869477762955837,
#   3.0,
#   'Audio processing.',
#   ['Audio visualization.', 'Audio recognition.']],
#  [481.0,
#   1094.0,
#   0.5434874159785994,
#   393.0,
#   'Innovation idea.',
#   ['Book concept.', 'Efficiency funding.']],
#  [138.0,
#   140.0,
#   0.5432952594565807,
#   2.0,
#   'Audio processing.',
#   ['Music dynamics: Compression', 'Audio distortion.']],
#  [342.0,
#   1096.0,
#   0.5449631341937496,
#   394.0,
#   'Knowledge creation.',
#   ['German natural sciences book.', 'Innovation idea.']],
#  [515.0,
#   1026.0,
#   0.5443897020749783,
#   5.0,
#   'Virtual experience.',
#   ['Virtual reality technology.', 'Virtual immersion.']],
#  [1090.0,
#   1098.0,
#   0.5458957129293315,
#   405.0,
#   'Information management.',
#   ['Asset control.', 'Knowledge creation.']],
#  [404.0,
#   1099.0,
#   0.5466760373000191,
#   406.0,
#   'Information management.',
#   ['Book/Business/Kindle', 'Information management.']],
#  [1066.0,
#   1100.0,
#   0.5784145539899995,
#   5.0,
#   'Signal processing.',
#   ['Digital signal processing', 'Electronic devices.']],
#  [1058.0,
#   1101.0,
#   0.5473966382931369,
#   408.0,
#   'Data organization.',
#   ['Coding principles.', 'Information management.']],
#  [1091.0,
#   1102.0,
#   0.5485603942099274,
#   411.0,
#   'Achievement strategy.',
#   ['Goal-oriented approach.', 'Data organization.']],
#  [154.0,
#   1103.0,
#   0.5502446874939987,
#   412.0,
#   'Pedagogical approach.',
#   ['Music education technique.', 'Achievement strategy.']],
#  [588.0,
#   593.0,
#   0.549757902581927,
#   2.0,
#   'Cognitive function.',
#   ['Mental fatigue.', 'Psychology concept.']],
#  [506.0,
#   1105.0,
#   0.5537871281515772,
#   413.0,
#   'Educational space.',
#   ['Library architecture', 'Pedagogical approach.']],
#  [185.0,
#   186.0,
#   0.5524137492893934,
#   2.0,
#   'Reggae star.',
#   ['Music Sheet', 'Song by Koffee.']],
#  [531.0,
#   587.0,
#   0.5533222701138296,
#   2.0,
#   'Entrepreneurship approach.',
#   ['Startup methodology.', 'Startup concept.']],
#  [284.0,
#   1108.0,
#   0.5554691638436067,
#   414.0,
#   'Artistic expression.',
#   ['Music manifesto.', 'Educational space.']],
#  [129.0,
#   1109.0,
#   0.569123810281366,
#   4.0,
#   'Switch control.',
#   ['Solid-state switches.', 'Electronics.']],
#  [1029.0,
#   1110.0,
#   0.557041894231298,
#   416.0,
#   'Creativity.',
#   ['Information processing.', 'Artistic expression.']],
#  [181.0,
#   1084.0,
#   0.5559315914592953,
#   16.0,
#   'Oxygen monitoring.',
#   ['Health condition: Hyperoxia.', 'Capturing data.']],
#  [1070.0,
#   1112.0,
#   0.5585161808546919,
#   433.0,
#   'Innovation.',
#   ['Technology', 'Creativity.']],
#  [191.0,
#   1010.0,
#   0.5581062355238114,
#   3.0,
#   'Arrangement.',
#   ['Jazz standard', 'Music production.']],
#  [151.0,
#   1114.0,
#   0.5610131163843642,
#   434.0,
#   'Fragmented thinking.',
#   ['Philosophy fragments', 'Innovation.']],
#  [1106.0,
#   1115.0,
#   0.5629863814034407,
#   5.0,
#   'Music genre.',
#   ['Reggae star.', 'Reggae']],
#  [147.0,
#   1064.0,
#   0.5605966149716729,
#   3.0,
#   'Technology knowledge.',
#   ['Computer science concept.', 'Computing skills.']],
#  [273.0,
#   1117.0,
#   0.5612054657556539,
#   435.0,
#   'Persuasive communication.',
#   ['Rhetorical tactics', 'Fragmented thinking.']],
#  [47.0,
#   1118.0,
#   0.5622797312876253,
#   436.0,
#   'Language influence.',
#   ['French savings account.', 'Persuasive communication.']],
#  [1111.0,
#   1119.0,
#   0.563811537114281,
#   452.0,
#   'Measurement correlation.',
#   ['Oxygen monitoring.', 'Language influence.']],
#  [1113.0,
#   1120.0,
#   0.5649178194544989,
#   8.0,
#   'Music style.',
#   ['Arrangement.', 'Music genre.']],
#  [165.0,
#   1121.0,
#   0.5649343622260834,
#   453.0,
#   'Math correlation.',
#   ['Mathematical postulates.', 'Measurement correlation.']],
#  [188.0,
#   1122.0,
#   0.5656507514376696,
#   9.0,
#   'Musical genre.',
#   ['Jazz music.', 'Music style.']],
#  [1061.0,
#   1123.0,
#   0.5656024689456159,
#   457.0,
#   'Problem-solving.',
#   ['Personal development.', 'Math correlation.']],
#  [1001.0,
#   1124.0,
#   0.5665819345825583,
#   459.0,
#   'Information management.',
#   ['Library system.', 'Problem-solving.']],
#  [188.0,
#   1122.0,
#   0.5656507514376696,
#   9.0,
#   'Musical genre.',
#   ['Jazz music.', 'Music style.']],
#  [26.0,
#   27.0,
#   0.5664157072383881,
#   2.0,
#   'Inflation.',
#   ['Economics: Hyperinflation.', 'Inflation warning.']],
#  [211.0,
#   1127.0,
#   0.5680768589888425,
#   460.0,
#   '"Personal development"',
#   ['Self-help book.', 'Information management.']],
#  [1087.0,
#   1128.0,
#   0.569615236704157,
#   492.0,
#   'Communication skills.',
#   ['Language analysis.', '"Personal development"']],
#  [129.0,
#   1109.0,
#   0.569123810281366,
#   4.0,
#   'Switch control.',
#   ['Solid-state switches.', 'Electronics.']],
#  [504.0,
#   1130.0,
#   0.5696286213113181,
#   493.0,
#   'Digital security.',
#   ['Cryptocurrency security (private key).', 'Communication skills.']],
#  [109.0,
#   1131.0,
#   0.5711604506183948,
#   494.0,
#   'Technology-based.',
#   ['Types of Learning: Aided/Unaided', 'Digital security.']],
#  [1125.0,
#   1132.0,
#   0.5743911657087307,
#   503.0,
#   'Electronic music.',
#   ['Musical genre.', 'Technology-based.']],
#  [774.0,
#   1133.0,
#   0.5839489374716785,
#   5.0,
#   'Sound production.',
#   ['Recording space.', 'Audio engineering.']],
#  [590.0,
#   1134.0,
#   0.5745071178343323,
#   504.0,
#   'Mental stimulation.',
#   ['Mindset classification.', 'Electronic music.']],
#  [1088.0,
#   1135.0,
#   0.5758743874174931,
#   510.0,
#   'Communication aid.',
#   ['Presentations.', 'Mental stimulation.']],
#  [189.0,
#   1092.0,
#   0.5745376501801973,
#   5.0,
#   'Musical arrangements.',
#   ['Music covers learned.', 'Structure.']],
#  [15.0,
#   1137.0,
#   0.5780919838569102,
#   511.0,
#   'Life stories.',
#   ['Biographies.', 'Communication aid.']],
#  [526.0,
#   1138.0,
#   0.5790901857876795,
#   512.0,
#   'Learning experiences.',
#   ['Education.', 'Life stories.']],
#  [1066.0,
#   1100.0,
#   0.5784145539899995,
#   5.0,
#   'Signal processing.',
#   ['Digital signal processing', 'Electronic devices.']],
#  [1020.0,
#   1140.0,
#   0.5840142671146487,
#   517.0,
#   'Acquiring knowledge.',
#   ['Epistemology quest.', 'Learning experiences.']],
#  [139.0,
#   1141.0,
#   0.5844722065625053,
#   6.0,
#   'Sound accuracy.',
#   ['Studio monitors - sound shaping.', 'Sound production.']],
#  [1116.0,
#   1142.0,
#   0.5842379251693536,
#   520.0,
#   'Learning process.',
#   ['Technology knowledge.', 'Acquiring knowledge.']],
#  [1107.0,
#   1143.0,
#   0.5849502210083655,
#   522.0,
#   'Innovation mindset.',
#   ['Entrepreneurship approach.', 'Learning process.']],
#  [139.0,
#   1141.0,
#   0.5844722065625053,
#   6.0,
#   'Sound accuracy.',
#   ['Studio monitors - sound shaping.', 'Sound production.']],
#  [145.0,
#   1145.0,
#   0.5858759056722069,
#   523.0,
#   'Technology innovation.',
#   ['Computer history timeline.', 'Innovation mindset.']],
#  [97.0,
#   1146.0,
#   0.5860299753900993,
#   524.0,
#   'Style.',
#   ['Fashion and Taste.', 'Technology innovation.']],
#  [875.0,
#   1147.0,
#   0.5862361793456958,
#   527.0,
#   'Approach',
#   ['Leadership perspective.', 'Style.']],
#  [1139.0,
#   1148.0,
#   0.5875227153826424,
#   532.0,
#   'Data analysis.',
#   ['Signal processing.', 'Approach']],
#  [59.0,
#   1093.0,
#   0.5869477762955837,
#   3.0,
#   'Audio processing.',
#   ['Audio visualization.', 'Audio recognition.']],
#  [153.0,
#   1150.0,
#   0.5877087610658703,
#   533.0,
#   'Information management.',
#   ['Personal knowledge management.', 'Data analysis.']],
#  [1097.0,
#   1151.0,
#   0.5886248936110673,
#   538.0,
#   'Digital realm.',
#   ['Virtual experience.', 'Information management.']],
#  [469.0,
#   1152.0,
#   0.5896595604711216,
#   539.0,
#   'Online critique.',
#   ['Book review.', 'Digital realm.']],
#  [1144.0,
#   1153.0,
#   0.5904486616586387,
#   545.0,
#   'Audio quality.',
#   ['Sound accuracy.', 'Online critique.']],
#  [591.0,
#   1154.0,
#   0.5911779930720166,
#   546.0,
#   'Distractions reduction.',
#   ['Social media detox', 'Audio quality.']],
#  [190.0,
#   1155.0,
#   0.5924824162238024,
#   547.0,
#   'Focus aid.',
#   ['Music sheet.', 'Distractions reduction.']],
#  [1047.0,
#   1156.0,
#   0.5937746660251357,
#   551.0,
#   'Productivity enhancement.',
#   ['Social interaction spaces.', 'Focus aid.']],
#  [1136.0,
#   1157.0,
#   0.5941083579392504,
#   556.0,
#   'Musical productivity.',
#   ['Musical arrangements.', 'Productivity enhancement.']],
#  [1129.0,
#   1158.0,
#   0.5987965805095196,
#   560.0,
#   'Manual dexterity.',
#   ['Switch control.', 'Musical productivity.']],
#  [524.0,
#   1159.0,
#   0.6017684767409062,
#   561.0,
#   '"lack of success"',
#   ['Productivity tool - failed.', 'Manual dexterity.']],
#  [537.0,
#   1160.0,
#   0.6036723219681985,
#   562.0,
#   'Failure.',
#   ['Psychology, Overconfidence, Bias.', '"lack of success"']],
#  [137.0,
#   1161.0,
#   0.6086876035120555,
#   563.0,
#   'Equipment malfunctions.',
#   ['Preamps - API, Manley.', 'Failure.']],
#  [1065.0,
#   1162.0,
#   0.611350891043737,
#   565.0,
#   'Problem-solving.',
#   ['Design synthesis.', 'Equipment malfunctions.']],
#  [528.0,
#   1163.0,
#   0.6118732211163941,
#   566.0,
#   'Innovation (or Creativity)',
#   ['Humorous automation project.', 'Problem-solving.']],
#  [1095.0,
#   1164.0,
#   0.6127083094284909,
#   568.0,
#   'Sound manipulation.',
#   ['Audio processing.', 'Innovation (or Creativity)']],
#  [533.0,
#   1165.0,
#   0.6128296669653408,
#   569.0,
#   'Innovation quest.',
#   ['Startup journey.', 'Sound manipulation.']],
#  [582.0,
#   1166.0,
#   0.6129973397722589,
#   570.0,
#   'Problem-solving.',
#   ['Heroku troubleshooting.', 'Innovation quest.']],
#  [1031.0,
#   1167.0,
#   0.6136850284594377,
#   572.0,
#   'Strategic thinking.',
#   ['Business Models.', 'Problem-solving.']],
#  [149.0,
#   1168.0,
#   0.6143650070897425,
#   573.0,
#   'Innovation strategy.',
#   ['Technology concept.', 'Strategic thinking.']],
#  [35.0,
#   1169.0,
#   0.6169035699753942,
#   574.0,
#   'Creative process.',
#   ['Writing platform.', 'Innovation strategy.']],
#  [79.0,
#   1170.0,
#   0.6211043907819984,
#   575.0,
#   'Imagination.',
#   ['Greek fiction.', 'Creative process.']],
#  [539.0,
#   1171.0,
#   0.6242533592295411,
#   576.0,
#   'Mental processes.',
#   ['Psychology/Expectation Effect.', 'Imagination.']],
#  [1126.0,
#   1172.0,
#   0.6250377763919195,
#   578.0,
#   'Cognition.',
#   ['Inflation.', 'Mental processes.']],
#  [133.0,
#   1173.0,
#   0.6259735943890321,
#   579.0,
#   'Information processing.',
#   ['Electronics components.', 'Cognition.']],
#  [1104.0,
#   1174.0,
#   0.6313859930131367,
#   581.0,
#   'Mental process.',
#   ['Cognitive function.', 'Information processing.']],
#  [32.0,
#   1175.0,
#   0.6345479470327451,
#   582.0,
#   'Emotional cognition.',
#   ['Music mood contrast.', 'Mental process.']],
#  [1149.0,
#   1176.0,
#   0.6366321282501017,
#   585.0,
#   'Sound analysis.',
#   ['Audio processing.', 'Emotional cognition.']],
#  [540.0,
#   1177.0,
#   0.6387197108226106,
#   586.0,
#   'Critical thinking.',
#   ['Questioning authority/morality.', 'Sound analysis.']],
#  [523.0,
#   1178.0,
#   0.643669345099342,
#   587.0,
#   'Cognition evolution.',
#   ['Brain-gut connection evolution.', 'Critical thinking.']],
#  [159.0,
#   1179.0,
#   0.6493339196867838,
#   588.0,
#   'Self-improvement.',
#   ['Premium mediocrity \nDomestic improvement', 'Cognition evolution.']],
#  [507.0,
#   1180.0,
#   0.6495255245017102,
#   589.0,
#   'Creativity.',
#   ['Interior design concept.', 'Self-improvement.']],
#  [161.0,
#   1181.0,
#   0.6512583633518024,
#   590.0,
#   'Lifelong learning.',
#   ['Middle age education.', 'Creativity.']],
#  [538.0,
#   1182.0,
#   0.6534076059965174,
#   591.0,
#   'Sustainability education.',
#   ['Energy consumption effect.', 'Lifelong learning.']],
#  [132.0,
#   1183.0,
#   0.6650496841274404,
#   592.0,
#   'Wiring sustainability.',
#   ['Audio wiring guide.', 'Sustainability education.']],
#  [37.0,
#   1184.0,
#   0.6775823734684764,
#   593.0,
#   'Neuroscience.',
#   ['Sensory perception.', 'Wiring sustainability.']],
#  [166.0,
#   1185.0,
#   0.6894115297255239,
#   594.0,
#   'Statistics brain mapping.',
#   ['Probability distribution.', 'Neuroscience.']],
#  [166.0,
#   1185.0,
#   0.6894115297255239,
#   594.0,
#   'Statistics brain mapping.',
#   ['Probability distribution.', 'Neuroscience.']]]
